# %% [markdown]
# # TFP Calculation

# %%
import pandas as pd, numpy as np
np.random.seed(5647)
import matplotlib.pyplot as plt
from numpy import log
df = pd.read_csv("/Users/pranjal/Desktop/Quantitative-Macroeconomics/Examples/gdp-hours.csv")
df = df[68:-2]
df['AWHI']=df['AWHI'].astype(float)
df['GDPC1']=df['GDPC1'].astype(float)
df["AWHI"] = log(df["AWHI"]);
df["GDPC1"] = log(df["GDPC1"]);
df["Z"] = df["GDPC1"] - (2/3)*df["AWHI"]; # TFP Calculation
df["Z(t-1)"] = df["Z"].shift(1)
df["T"] = range(1,df.shape[0]+1,1)
df = df.iloc[16:]

# %%
df["GDPC1"].plot()
# Out:
# <AxesSubplot:>

# %%
df["AWHI"].plot()
# Out:
# <AxesSubplot:>

# %%
df["Z"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pre Covid Only

# %%
df2 = df[1:207].dropna()
y = df2["Z"]
x = df2[["Z(t-1)", "T"]]

import statsmodels.api as sm
x = sm.add_constant(x) 
lin_model = sm.OLS(y, x)
regr_results = lin_model.fit()
print(regr_results.summary())

# σ, ρ estimate
from statsmodels.tools.eval_measures import rmse
ypred = regr_results.predict(x)
rmse = rmse(y, ypred)
print('\n', rmse, 0.99)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Z   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.883e+05
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        14:36:25   Log-Likelihood:                 787.81
# No. Observations:                 206   AIC:                            -1570.
# Df Residuals:                     203   BIC:                            -1560.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0574      0.085      0.672      0.503      -0.111       0.226
# Z(t-1)         0.9909      0.015     65.871      0.000       0.961       1.021
# T           3.377e-05   7.14e-05      0.473      0.637      -0.000       0.000
# ==============================================================================
# Omnibus:                        5.351   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                7.806
# Skew:                          -0.016   Prob(JB):                       0.0202
# Kurtosis:                       3.953   Cond. No.                     3.15e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  0.0052831227110779365 0.99

# %% [markdown]
# # Post Covid Included

# %%
df2 = df.dropna()
y = df2["Z"]
x = df2[["Z(t-1)", "T"]]

import statsmodels.api as sm
x = sm.add_constant(x) 
lin_model = sm.OLS(y, x)
regr_results = lin_model.fit()
print(regr_results.summary())

# σ, ρ estimate
from statsmodels.tools.eval_measures import rmse
ypred = regr_results.predict(x)
rmse = rmse(y, ypred)
print('\n', rmse, 0.986)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Z   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.831e+05
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        14:36:25   Log-Likelihood:                 809.24
# No. Observations:                 215   AIC:                            -1612.
# Df Residuals:                     212   BIC:                            -1602.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0827      0.081      1.016      0.311      -0.078       0.243
# Z(t-1)         0.9865      0.014     68.834      0.000       0.958       1.015
# T           5.277e-05   6.71e-05      0.786      0.433   -7.95e-05       0.000
# ==============================================================================
# Omnibus:                        8.199   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               15.184
# Skew:                           0.035   Prob(JB):                     0.000504
# Kurtosis:                       4.300   Cond. No.                     2.98e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  0.005611943666157062 0.986

# %% [markdown]
# # Simulate AR1 and Estimate its parameters

# %%
# Simulate AR1: Z(t) = ρZ(t-1) + e(t), e(t) ~ N(0,σ^2)
ρ, σ = 0.9, 2

def simulateAR1(ρ, σ, N = 5000):
    X = np.zeros(N)
    X[0] = Z[0]
    for t in range(N-1):
        X[t+1] = ρ*X[t] + np.random.normal(0,σ)
    return X

plt.plot(X)

# %%
y = X[1000:-2]
x = X[1001:-1]
import statsmodels.api as sm
lin_model = sm.OLS(y, x)
regr_results = lin_model.fit()
print(regr_results.summary())

# σ, ρ estimate
from statsmodels.tools.eval_measures import rmse
ypred = regr_results.predict(x)
rmse = rmse(y, ypred)

print('Estimated σ', rmse)
print('Estimated ρ',  0.9105)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.809
# Model:                            OLS   Adj. R-squared (uncentered):              0.809
# Method:                 Least Squares   F-statistic:                          1.695e+04
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        14:36:26   Log-Likelihood:                         -8384.1
# No. Observations:                3998   AIC:                                  1.677e+04
# Df Residuals:                    3997   BIC:                                  1.678e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8995      0.007    130.181      0.000       0.886       0.913
# ==============================================================================
# Omnibus:                        3.998   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.135   Jarque-Bera (JB):                4.339
# Skew:                          -0.015   Prob(JB):                        0.114
# Kurtosis:                       3.159   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Estimated σ 1.9702102709171416
# Estimated ρ 0.9105

# %% [markdown]
# # Discretize the AR1 with Tauchen Method

# %%
# Input: ρ, σ, K
# Output: KxK Transition Matrix
ρ, σ, K = 0.9, 2, 8
σy = σ/np.sqrt(1-ρ**2)
print(ρ, σ, K, σy)

import scipy.stats as stats
def tauchen(ρ, σ, K, m=3):
    Z = np.linspace(-m * σ/np.sqrt(1-ρ**2), m * σ/np.sqrt(1-ρ**2), K) # Shock Space
    F = lambda x: stats.norm.cdf(x, 0, σ) # CDF Function for Standard Normal
    α = Z[2] - Z[1] # Step Size
    P = np.zeros((K,K)) # Placeholder Transition Matrix
    # P[i,j] is probability of process going from Zi to Zj 
    for i in range(K):
        for j in range(K):
            if j == 1:
                P[i, j] = F(Z[j]+α/2-ρ*Z[i])
            elif j == K:
                P[i, j] = 1 - F(Z[j]-α/2-ρ*Z[i])
            else:
                P[i, j] = F(Z[j]+α/2-ρ*Z[i]) - F(Z[j]-α/2-ρ*Z[i])
        P[i, :] = P[i, :]/sum(P[i, :])
    return Z, α, F, P
        
Z, α, F, P = tauchen(ρ, σ, K, m=3)
np.round(P,2)
# Out:
# 0.9 2 8 4.588314677411236
# array([[0.36, 0.63, 0.01, 0.  , 0.  , 0.  , 0.  , 0.  ],
#        [0.07, 0.64, 0.28, 0.01, 0.  , 0.  , 0.  , 0.  ],
#        [0.  , 0.1 , 0.65, 0.24, 0.  , 0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.14, 0.67, 0.19, 0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.  , 0.19, 0.67, 0.14, 0.  , 0.  ],
#        [0.  , 0.  , 0.  , 0.  , 0.24, 0.65, 0.1 , 0.  ],
#        [0.  , 0.  , 0.  , 0.  , 0.01, 0.3 , 0.62, 0.07],
#        [0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.39, 0.6 ]])

# %% [markdown]
# # Simulate the Markov Process

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def simulateAR1(Z, P, N):
    X = np.zeros(N)
    X[0] = Z[0]
    for t in range(N-1):
        i = find_nearest(Z, X[t])
        X[t+1] = np.random.choice(Z, p=P[i,:])
    return X

X = simulateAR1(Z, P, 5000)
plt.plot(X)

# %% [markdown]
# # Model the Markov process as an AR(1)

# %%
y = X[1000:-2]
x = X[1001:-1]
import statsmodels.api as sm
lin_model = sm.OLS(y, x)
regr_results = lin_model.fit()
print(regr_results.summary())

# σ, ρ estimate
from statsmodels.tools.eval_measures import rmse
ypred = regr_results.predict(x)
rmse = rmse(y, ypred)

print('Estimated σ', rmse)
print('Estimated ρ',  0.9056)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.793
# Model:                            OLS   Adj. R-squared (uncentered):              0.793
# Method:                 Least Squares   F-statistic:                          1.528e+04
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        14:36:29   Log-Likelihood:                         -9001.6
# No. Observations:                3998   AIC:                                  1.801e+04
# Df Residuals:                    3997   BIC:                                  1.801e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8902      0.007    123.602      0.000       0.876       0.904
# ==============================================================================
# Omnibus:                       15.739   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.831
# Skew:                           0.008   Prob(JB):                     3.00e-05
# Kurtosis:                       3.353   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Estimated σ 2.299249868226604
# Estimated ρ 0.9056

# %% [markdown]
# # Repeat with K = 50

# %%
Z, α, F, P = tauchen(ρ, σ, K=50, m=3)
X = simulateAR1(Z, P, 5000)
y = X[1000:-2]
x = X[1001:-1]
import statsmodels.api as sm
lin_model = sm.OLS(y, x)
regr_results = lin_model.fit()
print(regr_results.summary())

# σ, ρ estimate
from statsmodels.tools.eval_measures import rmse
ypred = regr_results.predict(x)
rmse = rmse(y, ypred)

print('Estimated σ', rmse)
print('Estimated ρ',  0.9056)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.804
# Model:                            OLS   Adj. R-squared (uncentered):              0.804
# Method:                 Least Squares   F-statistic:                          1.637e+04
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        14:36:35   Log-Likelihood:                         -8365.9
# No. Observations:                3998   AIC:                                  1.673e+04
# Df Residuals:                    3997   BIC:                                  1.674e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8965      0.007    127.930      0.000       0.883       0.910
# ==============================================================================
# Omnibus:                        0.054   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.973   Jarque-Bera (JB):                0.046
# Skew:                          -0.008   Prob(JB):                        0.977
# Kurtosis:                       3.003   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Estimated σ 1.9612446523400007
# Estimated ρ 0.9056
